# %%
import numpy as np # linear algebra
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Yash Agarwal\Desktop\Datasets\loan_eligibility_dataset\loan\loan.csv")
# Out:
# C:\Users\Yash Agarwal\AppData\Local\Temp\ipykernel_18080\1229995670.py:1: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Yash Agarwal\Desktop\Datasets\loan_eligibility_dataset\loan\loan.csv")

# %%
df.shape
# Out:
# (2260668, 145)

# %%
df.head(1)
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     13.56        84.92     C        C1  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
#
#   settlement_amount  settlement_percentage settlement_term
# 0               NaN                    NaN             NaN
#
# [1 rows x 145 columns]

# %%
df.describe()
# Out:
#         id  member_id     loan_amnt   funded_amnt  funded_amnt_inv  \
# count  0.0        0.0  2.260668e+06  2.260668e+06     2.260668e+06
# mean   NaN        NaN  1.504693e+04  1.504166e+04     1.502344e+04
# std    NaN        NaN  9.190245e+03  9.188413e+03     9.192332e+03
# min    NaN        NaN  5.000000e+02  5.000000e+02     0.000000e+00
# 25%    NaN        NaN  8.000000e+03  8.000000e+03     8.000000e+03
# 50%    NaN        NaN  1.290000e+04  1.287500e+04     1.280000e+04
# 75%    NaN        NaN  2.000000e+04  2.000000e+04     2.000000e+04
# max    NaN        NaN  4.000000e+04  4.000000e+04     4.000000e+04
#
#            int_rate   installment    annual_inc  url           dti  ...  \
# count  2.260668e+06  2.260668e+06  2.260664e+06  0.0  2.258957e+06  ...
# mean   1.309291e+01  4.458076e+02  7.799243e+04  NaN  1.882420e+01  ...
# std    4.832114e+00  2.671737e+02  1.126962e+05  NaN  1.418333e+01  ...
# min    5.310000e+00  4.930000e+00  0.000000e+00  NaN -1.000000e+00  ...
# 25%    9.490000e+00  2.516500e+02  4.600000e+04  NaN  1.189000e+01  ...
# 50%    1.262000e+01  3.779900e+02  6.500000e+04  NaN  1.784000e+01  ...
# 75%    1.599000e+01  5.933200e+02  9.300000e+04  NaN  2.449000e+01  ...
# max    3.099000e+01  1.719830e+03  1.100000e+08  NaN  9.990000e+02  ...
#
#        deferral_term  hardship_amount  hardship_length  hardship_dpd  \
# count        10613.0     10613.000000          10613.0  10613.000000
# mean             3.0       155.006696              3.0     13.686422
# std              0.0       129.113137              0.0      9.728138
# min              3.0         0.640000              3.0      0.000000
# 25%              3.0        59.370000              3.0      5.000000
# 50%              3.0       119.040000              3.0     15.000000
# 75%              3.0       213.260000              3.0     22.000000
# max              3.0       943.940000              3.0     37.000000
#
#        orig_projected_additional_accrued_interest  \
# count                                 8426.000000
# mean                                   454.840802
# std                                    375.830737
# min                                      1.920000
# 25%                                    174.967500
# 50%                                    352.605000
# 75%                                    622.792500
# max                                   2680.890000
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount  \
# count                    10613.000000                  10613.000000
# mean                     11628.036442                    193.606331
# std                       7615.161123                    198.694368
# min                         55.730000                      0.010000
# 25%                       5628.730000                     43.780000
# 50%                      10044.220000                    132.890000
# 75%                      16114.940000                    284.180000
# max                      40306.410000                   1407.860000
#
#        settlement_amount  settlement_percentage  settlement_term
# count       33056.000000           33056.000000     33056.000000
# mean         5030.606922              47.775600        13.148596
# std          3692.027842               7.336379         8.192319
# min            44.210000               0.200000         0.000000
# 25%          2227.000000              45.000000         6.000000
# 50%          4172.855000              45.000000        14.000000
# 75%          6870.782500              50.000000        18.000000
# max         33601.000000             521.350000       181.000000
#
# [8 rows x 109 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Columns: 145 entries, id to settlement_term
# dtypes: float64(105), int64(4), object(36)
# memory usage: 2.4+ GB

# %%
df.shape
# Out:
# (2260668, 145)

# %%
#transform the loan-status into a binary variable where 'Charged Off' = 1 and 'Fully Paid' = 0.
df['loan_status_bin'] = df['loan_status'].map({'Charged Off': 1, 'Fully Paid': 0})

# %%
df.shape
# Out:
# (2260668, 146)

# %%
df.head(1)
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_last_payment_amount  \
# 0     13.56        84.92     C        C1  ...                          NaN
#
#   disbursement_method debt_settlement_flag  debt_settlement_flag_date  \
# 0                Cash                    N                        NaN
#
#   settlement_status settlement_date settlement_amount settlement_percentage  \
# 0               NaN             NaN               NaN                   NaN
#
#    settlement_term loan_status_bin
# 0              NaN             NaN
#
# [1 rows x 146 columns]

# %%
#distribution of grades

(df['grade'].value_counts().sort_index()/len(df)).plot.bar()
# Out:
# <AxesSubplot:>

# %%
# distribution of the employment length

def emp_to_num(emp_to_num):
    if pd.isna(emp_to_num):
        return None
    elif emp_to_num[2]=='+':
        return 10
    elif emp_to_num[0]=='<':
        return 0
    else:
        return int(emp_to_num[0])

df['emp_length_num'] = df['emp_length'].apply(emp_to_num)
(df['emp_length_num'].value_counts().sort_index()/len(df)).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (2260668, 147)

# %%
df.head(1)
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
#
#    int_rate  installment grade sub_grade  ... disbursement_method  \
# 0     13.56        84.92     C        C1  ...                Cash
#
#   debt_settlement_flag debt_settlement_flag_date  settlement_status  \
# 0                    N                       NaN                NaN
#
#   settlement_date settlement_amount settlement_percentage settlement_term  \
# 0             NaN               NaN                   NaN             NaN
#
#    loan_status_bin emp_length_num
# 0              NaN           10.0
#
# [1 rows x 147 columns]

# %%
# connection between employment length and default rate

df.groupby('emp_length_num')['loan_status_bin'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='emp_length_num'>

# %%
df['long_emp'] = df['emp_length'].apply(lambda x: 1*(x=='10+ years'))
df['short_emp'] = df['emp_length'].apply(lambda x: 1*(x=='1 year' or x=='< 1 year'))

# %%
df.shape
# Out:
# (2260668, 149)

# %%
df['long_emp']
# Out:
# 0          1
# 1          1
# 2          0
# 3          1
# 4          1
#           ..
# 2260663    1
# 2260664    0
# 2260665    1
# 2260666    0
# 2260667    0
# Name: long_emp, Length: 2260668, dtype: int64

# %%
df.head(1)
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN       2500         2500           2500.0   36 months
#
#    int_rate  installment grade sub_grade  ... debt_settlement_flag_date  \
# 0     13.56        84.92     C        C1  ...                       NaN
#
#   settlement_status settlement_date  settlement_amount settlement_percentage  \
# 0               NaN             NaN                NaN                   NaN
#
#   settlement_term loan_status_bin emp_length_num  long_emp short_emp
# 0             NaN             NaN           10.0         1         0
#
# [1 rows x 149 columns]

# %%
len(df)
# Out:
# 2260668

# %%
# the distirubtion of the interest rates

(df['int_rate'].plot.hist(bins=10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# the distirubtion of the interest rates

(df['int_rate']/len(df)).plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#the distribution of the annual income

df[df['annual_inc']<200000]['annual_inc'].plot.hist(bins=20)
df['annual_inc_log'] = df['annual_inc'].apply(np.log)

# %%
df['annual_inc_log']
# Out:
# 0          10.915088
# 1          11.407565
# 2          10.990027
# 3          11.429544
# 4          10.955183
#              ...
# 2260663    10.968198
# 2260664    10.308953
# 2260665    11.066638
# 2260666    11.002100
# 2260667    11.002100
# Name: annual_inc_log, Length: 2260668, dtype: float64

# %%
df.shape
# Out:
# (2260668, 150)

# %%
#the most common reasons for requesting a loan

(df['purpose'].value_counts()/len(df)).plot.bar()
# Out:
# <AxesSubplot:>

# %%
#connection between grades and default rate

df.groupby('grade')['loan_status_bin'].mean().plot.line()
# Out:
# <AxesSubplot:xlabel='grade'>

# %%
#connection between grades and interest rate

df.groupby('grade')['int_rate'].mean().plot.line(color='blue')
# Out:
# <AxesSubplot:xlabel='grade'>

# %%
#the distribution of loan term

(df['term'].value_counts()/len(df)).plot.bar(title='value counts')
# Out:
# <AxesSubplot:title={'center':'value counts'}>

# %%
#connection between term and default rate

df.groupby('term')['loan_status_bin'].mean().plot.bar(title='default rate')
# Out:
# <AxesSubplot:title={'center':'default rate'}, xlabel='term'>

# %%
#the distribution of home_ownership feature

(df['home_ownership'].value_counts()/len(df)).plot.bar(title='value counts')
# Out:
# <AxesSubplot:title={'center':'value counts'}>

# %%
#connection between home_ownership feature and default rate

df[(df['home_ownership']=='MORTGAGE') | (df['home_ownership']=='OWN')| (df['home_ownership']=='RENT')].groupby('home_ownership')['loan_status_bin'].mean().plot.bar(title='default rate')
# Out:
# <AxesSubplot:title={'center':'default rate'}, xlabel='home_ownership'>

# %%
#the distribution of installment (An installment loan is a type of agreement or contract involving a 
# loan that is repaid over time with a set number of scheduled payments; normally at least two payments are made towards the loan)

df['installment'].plot.hist(bins=40, title='installment')
# Out:
# <AxesSubplot:title={'center':'installment'}, ylabel='Frequency'>

# %%
# from sklearn.linear_model import LinearRegression
# lr = LinearRegression()
# lr.fit(df.groupby('sub_grade')['loan_status_bin'].mean().values.reshape(-1,1), y=df.groupby('sub_grade')['int_rate'].mean())

# %%
# import matplotlib.pyplot as plt
# plt.scatter(df.groupby('sub_grade')['loan_status_bin'].mean(), df.groupby('sub_grade')['int_rate'].mean())
# plt.plot(df.groupby('sub_grade')['loan_status_bin'].mean(), lr.predict(df.groupby('sub_grade')['loan_status_bin'].mean().values.reshape(-1,1)))
# plt.xlabel('default rate')
# plt.ylabel('interest rate')

# %%
# print('interest rate = ', lr.intercept_, '+', lr.coef_[0], '* default rate')

# %%
df.isnull().sum()
# Out:
# id                 2260668
# member_id          2260668
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
#                     ...
# loan_status_bin     957061
# emp_length_num      146907
# long_emp                 0
# short_emp                0
# annual_inc_log           4
# Length: 150, dtype: int64

# %%
df.shape
# Out:
# (2260668, 150)

# %%
index_names = df[ df['loan_status'] == 'Current' ].index
df.drop(index_names, inplace = True)

# %%
df.shape
# Out:
# (1340973, 150)

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term', 'loan_status_bin',
#        'emp_length_num', 'long_emp', 'short_emp', 'annual_inc_log'],
#       dtype='object', length=150)

# %%
df['loan_status'].unique()
# Out:
# array(['Fully Paid', 'Late (31-120 days)', 'In Grace Period',
#        'Charged Off', 'Late (16-30 days)', 'Default',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
df['loan_status_bin'].unique()
# Out:
# array([ 0., nan,  1.])

# %%
# index_names = df[ df['loan_status'] == ['Late (31-120 days)' or 'In Grace Period' or 'Late (16-30 days)' or 'Default' or
#                 'Does not meet the credit policy. Status:Fully Paid' or 'Does not meet the credit policy. Status:Charged Off']].index
# df.drop(index_names, inplace = True)

# %%
data=df

# %%
data.shape
# Out:
# (1340973, 150)

# %%
df = df.dropna(subset=['loan_status_bin'])

# %%
df.shape
# Out:
# (1303607, 150)

# %%
df['loan_status_bin'].unique()
# Out:
# array([0., 1.])

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'settlement_status', 'settlement_date', 'settlement_amount',
#        'settlement_percentage', 'settlement_term', 'loan_status_bin',
#        'emp_length_num', 'long_emp', 'short_emp', 'annual_inc_log'],
#       dtype='object', length=150)

# %%
df.isnull().sum()
# Out:
# id                 1303607
# member_id          1303607
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
#                     ...
# loan_status_bin          0
# emp_length_num       75454
# long_emp                 0
# short_emp                0
# annual_inc_log           0
# Length: 150, dtype: int64

# %%
df=df.dropna(axis=1)

# %%
df.shape
# Out:
# (1303607, 44)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'addr_state', 'delinq_2yrs', 'earliest_cr_line', 'open_acc',
#        'pub_rec', 'revol_bal', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_amnt', 'policy_code',
#        'application_type', 'acc_now_delinq', 'delinq_amnt', 'hardship_flag',
#        'disbursement_method', 'debt_settlement_flag', 'loan_status_bin',
#        'long_emp', 'short_emp', 'annual_inc_log'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.head(10)
# Out:
#      loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 100      30000        30000          30000.0   36 months     22.35
# 152      40000        40000          40000.0   60 months     16.14
# 170      20000        20000          20000.0   36 months      7.56
# 186       4500         4500           4500.0   36 months     11.31
# 215       8425         8425           8425.0   36 months     27.27
# 269      20000        20000          20000.0   60 months     17.97
# 271       6600         6600           6325.0   36 months     11.31
# 296       2500         2500           2475.0   36 months     13.56
# 369       4000         4000           4000.0   36 months     17.97
# 379       2700         2700           2675.0   36 months      8.19
#
#      installment grade sub_grade home_ownership  annual_inc  ...  \
# 100      1151.16     D        D5       MORTGAGE    100000.0  ...
# 152       975.71     C        C4       MORTGAGE     45000.0  ...
# 170       622.68     A        A3       MORTGAGE    100000.0  ...
# 186       147.99     B        B3           RENT     38500.0  ...
# 215       345.18     E        E5       MORTGAGE    450000.0  ...
# 269       507.55     D        D1           RENT     57000.0  ...
# 271       217.05     B        B3           RENT     45000.0  ...
# 296        84.92     C        C1           RENT     42000.0  ...
# 369       144.55     D        D1       MORTGAGE     60000.0  ...
# 379        84.85     A        A4            OWN     24000.0  ...
#
#     application_type acc_now_delinq delinq_amnt hardship_flag  \
# 100        Joint App            0.0         0.0             N
# 152        Joint App            0.0         0.0             N
# 170        Joint App            0.0         0.0             N
# 186       Individual            0.0         0.0             N
# 215        Joint App            0.0         0.0             N
# 269       Individual            0.0         0.0             N
# 271       Individual            0.0         0.0             N
# 296       Individual            0.0         0.0             N
# 369       Individual            0.0         0.0             N
# 379       Individual            0.0         0.0             N
#
#     disbursement_method debt_settlement_flag  loan_status_bin long_emp  \
# 100                Cash                    N              0.0        0
# 152                Cash                    N              0.0        0
# 170                Cash                    N              0.0        1
# 186                Cash                    N              0.0        1
# 215                Cash                    N              0.0        0
# 269                Cash                    N              0.0        0
# 271                Cash                    N              0.0        1
# 296                Cash                    N              0.0        0
# 369                Cash                    N              0.0        0
# 379                Cash                    N              0.0        0
#
#      short_emp  annual_inc_log
# 100          0       11.512925
# 152          1       10.714418
# 170          0       11.512925
# 186          0       10.558414
# 215          0       13.017003
# 269          0       10.950807
# 271          0       10.714418
# 296          0       10.645425
# 369          0       11.002100
# 379          0       10.085809
#
# [10 rows x 44 columns]

# %%
df=df.drop(['policy_code','collection_recovery_fee','recoveries','last_pymnt_amnt','application_type','disbursement_method',
            'hardship_flag',
            'debt_settlement_flag'],axis=1)

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.head(10)
# Out:
#      loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 100      30000        30000          30000.0   36 months     22.35
# 152      40000        40000          40000.0   60 months     16.14
# 170      20000        20000          20000.0   36 months      7.56
# 186       4500         4500           4500.0   36 months     11.31
# 215       8425         8425           8425.0   36 months     27.27
# 269      20000        20000          20000.0   60 months     17.97
# 271       6600         6600           6325.0   36 months     11.31
# 296       2500         2500           2475.0   36 months     13.56
# 369       4000         4000           4000.0   36 months     17.97
# 379       2700         2700           2675.0   36 months      8.19
#
#      installment grade sub_grade home_ownership  annual_inc  ...  \
# 100      1151.16     D        D5       MORTGAGE    100000.0  ...
# 152       975.71     C        C4       MORTGAGE     45000.0  ...
# 170       622.68     A        A3       MORTGAGE    100000.0  ...
# 186       147.99     B        B3           RENT     38500.0  ...
# 215       345.18     E        E5       MORTGAGE    450000.0  ...
# 269       507.55     D        D1           RENT     57000.0  ...
# 271       217.05     B        B3           RENT     45000.0  ...
# 296        84.92     C        C1           RENT     42000.0  ...
# 369       144.55     D        D1       MORTGAGE     60000.0  ...
# 379        84.85     A        A4            OWN     24000.0  ...
#
#     total_pymnt_inv total_rec_prncp total_rec_int total_rec_late_fee  \
# 100        30026.44         30000.0         26.44                0.0
# 152        40856.68         40000.0        856.68                0.0
# 170        20215.79         20000.0        215.79                0.0
# 186         4549.22          4500.0         49.22                0.0
# 215         8735.15          8425.0        310.15                0.0
# 269        20013.58         20000.0         13.58                0.0
# 271         6346.86          6600.0         22.81                0.0
# 296         2476.27          2500.0          1.29                0.0
# 369         4049.92          4000.0         49.92                0.0
# 379         2675.83          2700.0          0.84                0.0
#
#     acc_now_delinq delinq_amnt  loan_status_bin long_emp  short_emp  \
# 100            0.0         0.0              0.0        0          0
# 152            0.0         0.0              0.0        0          1
# 170            0.0         0.0              0.0        1          0
# 186            0.0         0.0              0.0        1          0
# 215            0.0         0.0              0.0        0          0
# 269            0.0         0.0              0.0        0          0
# 271            0.0         0.0              0.0        1          0
# 296            0.0         0.0              0.0        0          0
# 369            0.0         0.0              0.0        0          0
# 379            0.0         0.0              0.0        0          0
#
#      annual_inc_log
# 100       11.512925
# 152       10.714418
# 170       11.512925
# 186       10.558414
# 215       13.017003
# 269       10.950807
# 271       10.714418
# 296       10.645425
# 369       11.002100
# 379       10.085809
#
# [10 rows x 36 columns]

# %%
df=df.drop(['total_rec_late_fee','acc_now_delinq','delinq_amnt'],axis=1)

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'addr_state', 'delinq_2yrs', 'earliest_cr_line', 'open_acc',
#        'pub_rec', 'revol_bal', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp',
#        'total_rec_int', 'loan_status_bin', 'long_emp', 'short_emp',
#        'annual_inc_log'],
#       dtype='object')

# %%
df['out_prncp']
# Out:
# 100        0.0
# 152        0.0
# 170        0.0
# 186        0.0
# 215        0.0
#           ...
# 2260654    0.0
# 2260655    0.0
# 2260656    0.0
# 2260658    0.0
# 2260664    0.0
# Name: out_prncp, Length: 1303607, dtype: float64

# %%
df=df.drop(['out_prncp','out_prncp_inv'],axis=1)

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# df=df.drop(['policy_code','collection_recovery_fee'],axis=1)

# %%
df['grade']=df['grade'].map({'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6, 'G': 7})

# %%
df.head(5)
# Out:
#      loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 100      30000        30000          30000.0   36 months     22.35
# 152      40000        40000          40000.0   60 months     16.14
# 170      20000        20000          20000.0   36 months      7.56
# 186       4500         4500           4500.0   36 months     11.31
# 215       8425         8425           8425.0   36 months     27.27
#
#      installment  grade sub_grade home_ownership  annual_inc  ... total_acc  \
# 100      1151.16      4        D5       MORTGAGE    100000.0  ...      19.0
# 152       975.71      3        C4       MORTGAGE     45000.0  ...      37.0
# 170       622.68      1        A3       MORTGAGE    100000.0  ...      19.0
# 186       147.99      2        B3           RENT     38500.0  ...      25.0
# 215       345.18      5        E5       MORTGAGE    450000.0  ...      37.0
#
#     initial_list_status   total_pymnt total_pymnt_inv total_rec_prncp  \
# 100                   w  30026.442500        30026.44         30000.0
# 152                   w  40856.678960        40856.68         40000.0
# 170                   w  20215.792430        20215.79         20000.0
# 186                   w   4549.217149         4549.22          4500.0
# 215                   w   8735.148975         8735.15          8425.0
#
#     total_rec_int  loan_status_bin long_emp  short_emp  annual_inc_log
# 100         26.44              0.0        0          0       11.512925
# 152        856.68              0.0        0          1       10.714418
# 170        215.79              0.0        1          0       11.512925
# 186         49.22              0.0        1          0       10.558414
# 215        310.15              0.0        0          0       13.017003
#
# [5 rows x 31 columns]

# %%
df=df.drop(['sub_grade'],axis=1)

# %%
df.shape
# Out:
# (1303607, 30)

# %%
df2=df

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'purpose', 'addr_state', 'delinq_2yrs', 'earliest_cr_line', 'open_acc',
#        'pub_rec', 'revol_bal', 'total_acc', 'initial_list_status',
#        'total_pymnt', 'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'loan_status_bin', 'long_emp', 'short_emp', 'annual_inc_log'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1303607 entries, 100 to 2260664
# Data columns (total 30 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   loan_amnt            1303607 non-null  int64
#  1   funded_amnt          1303607 non-null  int64
#  2   funded_amnt_inv      1303607 non-null  float64
#  3   term                 1303607 non-null  object
#  4   int_rate             1303607 non-null  float64
#  5   installment          1303607 non-null  float64
#  6   grade                1303607 non-null  int64
#  7   home_ownership       1303607 non-null  object
#  8   annual_inc           1303607 non-null  float64
#  9   verification_status  1303607 non-null  object
#  10  issue_d              1303607 non-null  object
#  11  loan_status          1303607 non-null  object
#  12  pymnt_plan           1303607 non-null  object
#  13  purpose              1303607 non-null  object
#  14  addr_state           1303607 non-null  object
#  15  delinq_2yrs          1303607 non-null  float64
#  16  earliest_cr_line     1303607 non-null  object
#  17  open_acc             1303607 non-null  float64
#  18  pub_rec              1303607 non-null  float64
#  19  revol_bal            1303607 non-null  int64
#  20  total_acc            1303607 non-null  float64
#  21  initial_list_status  1303607 non-null  object
#  22  total_pymnt          1303607 non-null  float64
#  23  total_pymnt_inv      1303607 non-null  float64
#  24  total_rec_prncp      1303607 non-null  float64
#  25  total_rec_int        1303607 non-null  float64
#  26  loan_status_bin      1303607 non-null  float64
#  27  long_emp             1303607 non-null  int64
#  28  short_emp            1303607 non-null  int64
#  29  annual_inc_log       1303607 non-null  float64
# dtypes: float64(14), int64(6), object(10)
# memory usage: 308.3+ MB

# %%
df=df.drop(['issue_d','loan_status','addr_state','earliest_cr_line'],axis=1)

# %%
df_dummies = pd.get_dummies(df,drop_first=True) #get dummy for categorical features

# %%
drop_columns = df_dummies.columns[(df_dummies.mean()<0.01)] #drop all dummy-variables which contain not at least 1% ones
df_dummies.drop(drop_columns, axis=1, inplace=True)

# %%
df_dummies.shape
# Out:
# (1303607, 33)

# %%
import os

outname = 'loan_data_clean.csv'

outdir = r"C:\Users\Yash Agarwal\Desktop\Datasets\loan_eligibility_dataset\loan.csv"
if not os.path.exists(outdir):
    os.mkdir(outdir)

fullname = os.path.join(outdir, outname)    

df_dummies.to_csv(fullname)

# %%
df['loan_status_bin'].value_counts()
# Out:
# 0.0    1041952
# 1.0     261655
# Name: loan_status_bin, dtype: int64

# %% [markdown]
# ## CREATING TRAINING AND TEST DATA

# %%
X = df_dummies.drop('loan_status_bin', axis=1)
y = df_dummies['loan_status_bin']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
# drop_columns = df_dummies.columns[(df_dummies.mean()<0.01)] #drop all dummy-variables which contain not at least 1% ones
# df_dummies.drop(drop_columns, axis=1, inplace=True)

# %%
lr.fit(X_train,y_train)
# Out:
# C:\Users\Yash Agarwal\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred=lr.predict(X_test)

# %%
cf_matrix=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cf_matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
 
print('Precision: ',precision)
print('Recall: ',recall)
 
#Plotting Precision-Recall Curve
disp = plot_precision_recall_curve(lr, X_test, y_test)
# Out:
# Precision:  0.9999615894294109
# Recall:  0.9995200798587115
# C:\Users\Yash Agarwal\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_precision_recall_curve is deprecated; Function `plot_precision_recall_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: PrecisionRecallDisplay.from_predictions or PrecisionRecallDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn import metrics
auc = metrics.roc_auc_score(y_test, y_pred)

false_positive_rate, true_positive_rate, thresolds = metrics.roc_curve(y_test, y_pred)

# %%
plt.figure(figsize=(10, 8), dpi=100)
plt.axis('scaled')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.title("AUC & ROC Curve")
plt.plot(false_positive_rate, true_positive_rate, 'g')
plt.fill_between(false_positive_rate, true_positive_rate, facecolor='lightgreen', alpha=0.7)
plt.text(0.95, 0.05, 'AUC = %0.4f' % auc, ha='right', fontsize=12, weight='bold', color='blue')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()

# %%
from sklearn.metrics import f1_score
print(f1_score(y_test,y_pred))
# Out:
# 0.9997407858987528

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Using cached lightgbm-3.3.2-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: wheel in c:\users\yash agarwal\anaconda3\lib\site-packages (from lightgbm) (0.37.1)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\yash agarwal\anaconda3\lib\site-packages (from lightgbm) (1.0.2)
# Requirement already satisfied: scipy in c:\users\yash agarwal\anaconda3\lib\site-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: numpy in c:\users\yash agarwal\anaconda3\lib\site-packages (from lightgbm) (1.21.5)
# Requirement already satisfied: joblib>=0.11 in c:\users\yash agarwal\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yash agarwal\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.2.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## LGB

# %%
import lightgbm as lgb

# %%
d_train=lgb.Dataset(X_train,label=y_train)

# %%
params={'learning_rate':0.05,'boosting_type':'gbdt','objective':'binary',
        'metric':['auc','binary_logloss'],'num_leaves':100,'max_depth':10}

# %%
clf=lgb.train(params,d_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 209563, number of negative: 833322
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039096 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3039
# [LightGBM] [Info] Number of data points in the train set: 1042885, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.200945 -> initscore=-1.380396
# [LightGBM] [Info] Start training from score -1.380396

# %%
y_pred_lgb=clf.predict(X_test)

# %%
y_pred_lgb
# Out:
# array([0.99493349, 0.00243085, 0.00227622, ..., 0.00201218, 0.00186207,
#        0.00211293])

# %%
for i in range(0,X_test.shape[0]):
    if y_pred_lgb[i]>=0.5:
        y_pred_lgb[i]=1
    else:
        y_pred_lgb[i]=0

# %%
y_pred_lgb
# Out:
# array([1., 0., 0., ..., 0., 0., 0.])

# %%
print(confusion_matrix(y_test,y_pred_lgb))
cm_lgb=confusion_matrix(y_test,y_pred_lgb)
# Out:
# [[208627      3]
#  [   223  51869]]

# %%
sns.heatmap(cm_lgb,annot=True)
# Out:
# <AxesSubplot:>

# %%
precision = precision_score(y_test, y_pred_lgb)
recall = recall_score(y_test, y_pred_lgb)
 
print('Precision: ',precision)
print('Recall: ',recall)
 
#Plotting Precision-Recall Curve
# disp = plot_precision_recall_curve(clf, X_test, y_test)
# Out:
# Precision:  0.9999421653300432
# Recall:  0.9957191123397067

# %%
metrics.roc_auc_score(y_test, y_pred_lgb)
# Out:
# 0.9978523664080742

# %%
print(f1_score(y_test,y_pred_lgb))
# Out:
# 0.9978261705975144
